# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/Users/elnazshahzeidi/Downloads/learningSet.csv')
data
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
# Check for null values in all columns


null_counts = data.isna().sum()
null_counts
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64

# %%
# Create a drop list for specified columns

drop_list = ['OSOURCE', 'ZIP']
drop_list
# Out:
# ['OSOURCE', 'ZIP']

# %%
# Identify columns with over 85% missing values

missing_percentage = pd.DataFrame(data.isna().sum()*100/len(data), columns=['percentage'])
missing_percentage.sort_values('percentage', ascending = False).head(50)
# Out:
#           percentage
# RDATE_5    99.990567
# RAMNT_5    99.990567
# RDATE_3    99.746363
# RAMNT_3    99.746363
# RDATE_4    99.705488
# RAMNT_4    99.705488
# RAMNT_6    99.186685
# RDATE_6    99.186685
# RAMNT_15   92.388798
# RDATE_15   92.388798
# RDATE_23   91.763091
# RAMNT_23   91.763091
# RDATE_20   91.732696
# RAMNT_20   91.732696
# RAMNT_7    90.677273
# RDATE_7    90.677273
# RAMNT_17   90.146942
# RDATE_17   90.146942
# RDATE_21   90.029556
# RAMNT_21   90.029556
# RAMNT_10   89.035970
# RDATE_10   89.035970
# RDATE_13   87.160944
# RAMNT_13   87.160944
# NUMCHLD    87.018404
# RDATE_11   84.551209
# RAMNT_11   84.551209
# RDATE_19   83.359535
# RAMNT_19   83.359535
# RAMNT_9    82.461326
# RDATE_9    82.461326
# RDATE_24   81.409047
# RAMNT_24   81.409047
# RAMNT_18   79.270951
# RDATE_18   79.270951
# RAMNT_22   78.123297
# RDATE_22   78.123297
# RAMNT_8    77.495493
# RDATE_8    77.495493
# RDATE_14   75.561774
# RAMNT_14   75.561774
# RAMNT_12   73.064185
# ...

# %%
# Remove columns with over 85% missing values

columns_to_drop = list(missing_percentage[missing_percentage['percentage'] >= 85].index)
print(len(columns_to_drop))


drop_list.extend(columns_to_drop)
len(drop_list)
# Out:
# 25
# 27

# %%
# Remove the specified columns from the DataFrame

data.drop(columns=drop_list, inplace=True)
data
# Out:
#        ODATEDW  TCODE STATE MAILCODE PVASTATE   DOB NOEXCH RECINHSE RECP3  \
# 0         8901      0    IL                    3712      0
# 1         9401      1    CA                    5202      0
# 2         9001      1    NC                       0      0
# 3         8701      0    CA                    2801      0
# 4         8601      0    FL                    2001      0        X     X
# ...        ...    ...   ...      ...      ...   ...    ...      ...   ...
# 95407     9601      1    AK                       0      0
# 95408     9601      1    TX                    5001      0
# 95409     9501      1    MI                    3801      0              X
# 95410     8601      0    CA                    4005      0        X
# 95411     8801      2    NC                    1801      0        X
#
#       RECPGVG  ... TARGET_D HPHONE_D RFA_2R RFA_2F  RFA_2A MDMAUD_R MDMAUD_F  \
# 0              ...      0.0        0      L      4       E        X        X
# ...

# %%
# Check current value counts in the GENDER column

data['GENDER'].value_counts()
# Out:
# GENDER
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: count, dtype: int64

# %%
# Fill null values
data['GENDER'] = data['GENDER'].fillna('F')  # Assuming 'F' for nulls; adjust if necessary

# Use a lambda function to categorize the GENDER values
data['GENDER'] = data['GENDER'].apply(lambda x: 'M' if x in ['M', 'Male'] else ('F' if x in ['F', 'Female'] else 'Other'))

# %%
 data['GENDER'].value_counts()
# Out:
# GENDER
# F        51277
# M        39094
# Other     5041
# Name: count, dtype: int64
